# %% [markdown]
# # Plots

# %% [markdown]
# if your dataset is in your hard disk then
#        upload it to the googlecolab using 'Files -> upload' by default it is stored in contents 'folder'
# if your file is in your google drive, first mount the drive using below code
#          from google.colab import drive
#          drive.mount('/content/gdrive')
# Executing the above code  will provide you an authentication link. Allow Google Drive Stream access to your Google Account.Once the Drive is mounted, you will be able to browse through the contents of your Drive from the file-explorer pane.
#
# If the file uploaded is a csv file read_csv() can be used to read the content of the file uploaded and store it into a dataframe
#     import pandas as pd
#     dataframe_name=pd.read_csv("Path of the file")
# if the dataset is in git in the above two line of code, instead  of 'path of the file' use 'url of the git'

# %%
#Read csv file and convert it to a data frame
import pandas as pd
stud_df=pd.read_csv("/students.csv")

# %%
stud_df.shape
# Out:
# (54, 6)

# %%
stud_df.head()
# Out:
#             Name  Gender  Attendance  Series1  Series2  FinalMark
# 0   ABHIJITH V A    Male          76     18.8     15.2         60
# 1   ABHISHEK K M    Male          76     15.0     16.4          0
# 2  AISWARYA RAJU  Female          87     16.0     19.6         80
# 3      AJINS U A    Male          83     19.2     13.6         90
# 4     AJOSH JOHN    Male          90     14.6     19.6         80

# %%
stud_df.tail()
# Out:
#                      Name  Gender  Attendance  Series1  Series2  FinalMark
# 49     STAINCY SARA SHAJI  Female          86     16.8     14.8         80
# 50          VARUN VINCENT    Male         100     18.6     19.6        100
# 51         VENKETESH ANIL    Male          92     14.2     13.4         70
# 52     VIJAYALAKSHMI BIJU  Female          97     19.6     18.4         90
# 53  JAYASREE MURALEDHARAN  Female          76     12.8     15.0         79

# %%
stud_df.isnull()

# %%
stud_df.isnull().sum()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
p=sns.countplot(x ='Gender', data = stud_df,hue='Gender')
#p=set_title('Number Girl and Boys students')
p.set_xlabel('Gender')
p.set_ylabel('Students number')
plt.show()

# %%
#scatter and Line Plots
plt.scatter(stud_df['Attendance'],stud_df['FinalMark'])
plt.show()

# %% [markdown]
# #### Slicing A DataFrame Using The `iloc[]` Function

# %% [markdown]
# **Syntax:**
#
# `dataframe_name.iloc[row_position_start : row_position_end, column_position_start : column_position_end]`
#
# In this syntax:
#
# - `row_position_start` denotes the position of the row in the DataFrame **starting** from whose values you want to take in the new Pandas series or DataFrame.
# - `row_position_end` denotes the position of the row in the DataFrame till whose values you want to take in the new Pandas series or DataFrame.
# - `column_position_start` denotes the position of the column in the DataFrame **starting** from whose values you want to take in the new Pandas series or DataFrame.
# - `column_position_end` denotes the position of the column in the DataFrame till whose values you want to take in the new Pandas series or DataFrame.
#
# You can verify manually whether we have extracted the values from the first row or not by viewing the first 5 rows of the DataFrame using the `head()` function.

# %%
# Create a Pandas series for the first student and store it in a variable called 'stud_0'.
stud_0 = stud_df.iloc[0, :]
stud_0
# Out:
# Name          ABHIJITH V A
# Gender                Male
# Attendance              76
# Series1               18.8
# Series2               15.2
# FinalMark               60
# Name: 0, dtype: object

# %%
# Create a Pandas series for the second student and store it in a variable called 'stud_1'.
stud_1 = stud_df.iloc[1,:]
stud_1
# Out:
# Name          ABHISHEK K M
# Gender                Male
# Attendance              76
# Series1               15.0
# Series2               16.4
# FinalMark                0
# Name: 1, dtype: object

# %%
# Create a Pandas series for the last student and store it in a variable called 'stud_54'.
stud_54 = stud_df.iloc[-1,:]
stud_54
# Out:
# Name          JAYASREE MURALEDHARAN
# Gender                       Female
# Attendance                       76
# Series1                        12.8
# Series2                        15.0
# FinalMark                        79
# Name: 53, dtype: object

# %%
# Create a Pandas series for the last 2 students and store it in a variable called 'stud'.
stud=stud_df.iloc[-2:,:]
stud
# Out:
#                      Name  Gender  Attendance  Series1  Series2  FinalMark
# 52     VIJAYALAKSHMI BIJU  Female          97     19.6     18.4         90
# 53  JAYASREE MURALEDHARAN  Female          76     12.8     15.0         79

# %%
# Create a Pandas series for the 'FinalMark' and store it in a variable called 'Final''.
Final=stud_df.iloc[:,-1]
Final.head()
# Out:
# 0    60
# 1     0
# 2    80
# 3    90
# 4    80
# Name: FinalMark, dtype: int64
